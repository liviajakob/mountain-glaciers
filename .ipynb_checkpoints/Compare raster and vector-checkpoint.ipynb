# %%
# %matplotlib notebook

import matplotlib as mpl
#import DataSetQuery
import datetime
import pandas as pd
#import MalardHelpers
import geopandas as gp
import matplotlib.pyplot as plt
import rasterio
from rasterio.plot import show
from rasterio.mask import mask
from shapely.geometry import Polygon, Point
from osgeo import gdal
import os
import numpy as np
from scipy.interpolate import griddata
import pandas as  pd
import geopandas as gp
from osgeo import gdal
import os
import json
import math
from pandas.io.json import json_normalize
import statsmodels.api as sm
from matplotlib.colors import LinearSegmentedColormap
from IPython.display import display

# %%
dfStats = gp.read_file("regression_results/iceland.gpkg")

dfStats.plot(color='red')
dfNew.plot(color='blue')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
print(dfStats.projection)
print('projection=+proj=stere +lat_0=90 +lat_ts=70 +lon_0=0 +x_0=0 +y_0=0 +datum=WGS84 +units=m +no_defs')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-f0caedd18703> in <module>
# ----> 1 print(dfStats.projection)
#
# /home/earthwave/miniconda3/envs/dev/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'GeoDataFrame' object has no attribute 'projection'

# %%
pd.DataFrame((dfStats['geometry'], dfStats['minX'], dfStats['maxX']))
# Out:
#                                      0                               1    \
# geometry  POINT (-871400.25 -2657427.25)  POINT (-870900.25 -2657427.25)
# minX                             -871900                         -871400
# maxX                             -870900                         -870400
#
#                                      2                               3    \
# geometry  POINT (-870400.25 -2657427.25)  POINT (-869900.25 -2657427.25)
# minX                             -870900                         -870400
# maxX                             -869900                         -869400
#
#                                      4                               5    \
# geometry  POINT (-869400.25 -2657427.25)  POINT (-868900.25 -2657427.25)
# minX                             -869900                         -869400
# maxX                             -868900                         -868400
#
#                                      6                               7    \
# ...

# %%
size=500
geometry = [Point(xy) for xy in zip(dfStats['minX']+(size/2), dfStats['minY']+(size/2))]
#dfNew=dfStats
#dfNew['geometry']=geometry
dfNew = gp.GeoDataFrame(dfStats, crs='EPSG:3995and', geometry=geometry)
dfNew
# Out:
#           maxX        maxY       minX        minY  regression.rsquared  \
# 0   -870900.25 -2656927.25 -871900.25 -2657927.25             0.285031
# 1   -870400.25 -2656927.25 -871400.25 -2657927.25             0.205629
# 2   -869900.25 -2656927.25 -870900.25 -2657927.25             0.110587
# 3   -869400.25 -2656927.25 -870400.25 -2657927.25             0.081677
# 4   -868900.25 -2656927.25 -869900.25 -2657927.25             0.004716
# 5   -868400.25 -2656927.25 -869400.25 -2657927.25             0.023431
# 6   -867900.25 -2656927.25 -868900.25 -2657927.25             0.067024
# 7   -867400.25 -2656927.25 -868400.25 -2657927.25             0.100583
# 8   -866900.25 -2656927.25 -867900.25 -2657927.25             0.395954
# 9   -866400.25 -2656927.25 -867400.25 -2657927.25             0.708843
# 10  -865900.25 -2656927.25 -866900.25 -2657927.25             0.452329
# 11  -865400.25 -2656927.25 -866400.25 -2657927.25             0.231706
# ...
